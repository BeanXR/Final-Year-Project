# %%
# Using yoloV5 to Train and Test

# %%
# %cd yolov5

import torch
from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

from IPython.display import HTML
import io
import base64

import matplotlib.pyplot as plt 
import cv2

print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# C:\Users\Robin Ng\Desktop\FYP\FYP_code\yolo\yolov5
# Setup complete. Using torch 1.6.0+cu101 _CudaDeviceProperties(name='GeForce RTX 2070', major=7, minor=5, total_memory=8192MB, multi_processor_count=36)

# %% [markdown]
# # Train

# %%
# !python train.py --device 0 --img 3024 --batch 16 --epochs 50 --data ./data/Dataset.yaml --cfg ./models/yolov5s.yaml --weights '' --nosave --cache
# Out:
# ^C

# %% [markdown]
# # Visualise

# %%
# directory is already in yolov5
Image(filename='runs/exp5/train_batch1.jpg', width=500)  # view augmented training mosaics

# %% [markdown]
# # Test

# %%
# !python test.py --weights ./runs/exp10/weights/last.pt --data ./data/dataset.yaml --task test
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/dataset.yaml', device='', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['./runs/exp10/weights/last.pt'])
# Fusing layers...
#                  all          50          50       0.443        0.98       0.859       0.493
# Speed: 2.8/2.2/5.0 ms inference/NMS/total per 640x640 image at batch-size 32
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2070', total_memory=8192MB)
#
# Model Summary: 140 layers, 7.24652e+06 parameters, 0 gradients
#
# ...
# Scanning images: 100%|##########| 50/50 [00:00<00:00, 175.90it/s]
#
# 0it [00:00, ?it/s]
# Scanning labels dataset\labels\test.cache (50 found, 0 missing, 0 empty, 0 duplicate, for 50 images): 50it [00:00, 24975.01it/s]
#
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Visualize Test Input and Output

# %%
figure,axes = plt.subplots(1,2,figsize=(10,8))
axes[0].set_title('Input')
axes[0].imshow(cv2.cvtColor( cv2.imread('test_batch0_pred.jpg') , cv2.COLOR_BGR2RGB ) )
axes[1].set_title('Output') 
axes[1].imshow(cv2.cvtColor( cv2.imread('test_batch0_gt.jpg') , cv2.COLOR_BGR2RGB ) )

# %% [markdown]
# # Test on Video

# %%
# !python detect.py --classes 0 1 --weights ./runs/resized_50_epochs_with_me/weights/last.pt --img 640 --source 0
